# %% [markdown]
# # betting options

# %%
# test example
bet_options = {'bet_input': 0, #___Bet_Bins___
               'bet_max': [100, True],
               'bet_text': 'How much do you want to bet this round?  ',
               'bet_help': ['Your options are:',
                            f"Any whole positive integer that is less than or equal to your remaining funds of {'player_stack'}."],
               'bet_default': 10}

# %% [markdown]
# # tbd

# %%
if skill_options['skill_input'] == 'P':

# %%
bummer = 1
test = f"test {bummer}"
print(test)
# Out:
# test 1

# %% [markdown]
# # Shuffle

# %%
#_____________________________________________________
# mid-game shuffle            
def shuffle_deck(shoe_deck, discard_deck, cut_target, shuffle_trigger):
    # reassemble + shuffle deck
    shoe_deck, discard_deck = rotary_shuffing(shoe_deck,discard_deck)
    # generate new cut target
    cut_target = random.randint(49,(len(shoe_deck['suits']) - 51))
    # reset bin
    shuffle_trigger = False

# %% [markdown]
# # expandable bin code

# %%
#(turn_options_1, turn_options_2, turn_options_3, bet_options, dealer_hand, player_hand, mode_options, skill_options)

# initial setup
draw_count = 0
dealer = new_deck()
player_1 = new_deck()
hands = [player_1]

play_mode = mode_options['mode_input']
skill_mode = skill_options['skill_input']
draw_live = True #round reset
bets_live = False #bet reset
dual_hands = False

player_1 = new_deck()
hands = [player_1]

bet_1 = 0
bets = [bet_1]

# print setting
    if skill_mode = "P":
        player_hand_text = player['suits']
        dealer_single_text = dealer['suits'][0]
        dealer_hand_text = dealer['suits'][0]
        bets_live = True
    else:
        player_hand_text = sum(player['values'])
        dealer_single_text = dealer['values'][0]
        dealer_hand_text = sum(dealer['values'])
        
    #print(f"Dealer is showing {dealer_single_text}")
    #print(f"Your hand is {player_hand_text}. What would you like to do?")
    #print(f"Better luck next round. The dealer managed to beat you with {dealer_hand_text}.")

# main loop
    while draw_live = True:
        
        # sub loop per hand
        for hand in len(hands):

            # dictionary selection
            if draw_count = 0:
                if player_hand['values'][0] == player_hand['values'][1]:
                    hand_options = turn_options_1
                else:
                    hand_options = turn_options_2
            else:
                hand_options = turn_options_3

           #_____________________________________________________      
            # Instant round check
            if sum(dealer['values']) == 21 and sum(player['values']) == 21:
                print('Both you and the dealer were dealt blackjacks. This round is a draw.')
                draw_live = False
            elif sum(dealer['values']) == 21:
                print('Dealer was dealt a blackjack. Better luck next round.')
                draw_live = False

            # Standard game loop
            else:
                
                # bet check
                if bets_live:
                    input_loop(bet_options)
                
                # initiate input prompt
                input_loop(x_options)

                # dictionary seperation
                input_selection = x_options[list(x_option.keys())[0]]

                # bet check
                if bets_live:
                    
                    for hand in len(hands):
                        current_bet = bets[hand]

                        # split selected
                        if play_input == "T":
                            # adds new bins
                            bets.append([])

                            #bin updates
                            bets[hand+1] = bets[hand]
                            bet_options['bet_max'][0] -= bets[hand+1]
                            
                        if input_selection == 'D':
                            bets[hand] = (bets[hand])*2
                            bet_options['bet_max'][0] -= bets[hand]
                            
                        if input_selection == 'F':
                            bets[hand] = bets[hand]
                        
                
                # handling cards
                if input_selection == 'S':
                    draw_live = False

                if input_selection == 'H':
                    #

                if input_selection == 'T':
                    hands.append([])
                    # steal first card and place into new hand
                    for key in ["suits", "values", "ids"]:
                        hands[hand+1][key].append(hands[hand][key].pop(0))
                        
                    # new secondary cards
                    for key in ["suits", "values", "ids"]:
                        hands[hand][key].append(shoe_deck[key].pop(0))
                        hands[hand+1][key].append(shoe_deck[key].pop(0))

                if input_selection == 'D':
                    #

                if input_selection == 'F':
                    draw_live = False

# %% [markdown]
# # deal code

# %%
#____________________________________________________   
# Variable loop to check for valid inputs from the user
def deal_loop(x_options_1, x_options_2, x_options_3, bet_options, dealer_hand, player_hand, mode_options, skill_options)

    # initial setup
    draw_count = 0
    dealer = new_deck()
    player_1 = new_deck()
    play_mode = mode_options['mode_input']
    skill_mode = skill_options['skill_input']
    draw_live = True #round reset
    bets_live = False #bet reset
    dual_hands = False
      
    # print setting
    if skill_mode = "P":
        player_card_text = player['suits']
        dealer_card_text = dealer['suits']
        bets_live = True
    else:
        player_card_text = sum(player['values'])
        dealer_card_text = sum(dealer['values'])

    # initial draws
    for deal in range(2):
        for key in ["suits", "values", "ids"]:
            dealer[key].append(master_deck[key].pop(0))
        for key in ["suits", "values", "ids"]:
            player[key].append(master_deck[key].pop(0))
            
    # main loop
    while draw_live = True:

        # dictionary selection
        if draw_count = 0:
            if player_hand['values'][0] == player_hand['values'][1]:
                x_option = x_options_1
            else:
                x_option = x_options_2
        else:
            x_option = x_options_3

        # initiate input prompt
        input_loop(x_options)

        # dictionary seperation
        input_selection = x_options[list(x_option.keys())[0]]

        #_____________________________________________________      
        # Instant round check
        if sum(dealer['values']) == 21 and sum(player['values']) == 21:
            print('Both you and the dealer were dealt blackjacks. This round is a draw.')
            draw_live = False
        elif sum(dealer['values']) == 21:
            print('Dealer was dealt a blackjack. Better luck next round.')
            draw_live = False

        # Standard game loop
        else:
            
            if input_selection == 'S':
                draw_live = False

            if input_selection == 'H':
                #

            if input_selection == 'T':
                dual_hands = True

            if input_selection == 'D':
                #

            if input_selection == 'F':
                bet =
                draw_live = False

# %% [markdown]
# # bet logic

# %%
# min bet check
if bet_options['bet_max'][1] = True:
    
    # bet input
    input_loop(bet_options)

    # bin updates
    bet_1 = bet_options['bet_input']
    bet_options['bet_max'][0] -= bet_options['bet_input']
    # min bet update
    if bet_options['bet_max'][0] < 10:
        bet_options['bet_max'][1] = False

    bet_1['hand_bet'] = int(hand_jackpot)

    if hands >= 1:
        bet_2 = bet_structure()
        bet_2 = bet_1['hand_bet']
else: 
    game_live = False
    print("You don't have enough to meet the minimum bet. Looks like it's game over. Better luck next time")

# %% [markdown]
# # game loop

# %%
# initial status update
game_live = True

# loop for  rounds
while game_live:
    #_____________________________________________________
    # Shuffle if trigger updated
    if shuffle_trigger:
        master_deck, discard_deck = rotary_shuffling(master_deck, discard_deck)
        shuffles += 1
        # generate new cut target
        cut_target = random.randint(49,(len(master_deck['suits']) - 51))
        print("Deck shuffled.")
    
    # Shuffle next round if cut target is reached
    if len(master_deck['suits']) <= cut_target:
        print("Cut-Card drawn. Deck to be shuffled next round.")
        shuffle_trigger = True
        
    #_____________________________________________________
    # Initial Draws
    
    for deal in range(2):
        for key in ["suits", "values", "ids"]:
            dealer[key].append(master_deck[key].pop(0))
        for key in ["suits", "values", "ids"]:
            player[key].append(master_deck[key].pop(0))
    
    evaluate_round(player, dealer, win_rates)
    
    #_____________________________________________________      
    # Instant round check
    if sum(dealer['values']) == 21 and sum(player['values']) == 21:
        print('Both you and the dealer were dealt blackjacks. This round is a draw.')
    elif sum(dealer['values']) == 21:
        print('Dealer was dealt a blackjack. Better luck next round.')

# %%
#(S)tand, (H)it, spli(T), (D)ouble, (F)old
#(S)tand, (H)it, (D)ouble, (F)old
#(S)tand, (H)it
